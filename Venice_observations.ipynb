# %%
import sys 
import pandas as pd 
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt 
import datetime as dt
import seaborn as sns

# %%
venice = pd.read_csv('~/Downloads/venice_listings.csv', delimiter = ',', header = 0, low_memory=False)

# %%
venice.head()
# Out:
#          id                            listing_url  \
# 0  33080794  https://www.airbnb.com/rooms/33080794
# 1      6623      https://www.airbnb.com/rooms/6623
# 2      6624      https://www.airbnb.com/rooms/6624
# 3     12074     https://www.airbnb.com/rooms/12074
# 4     27116     https://www.airbnb.com/rooms/27116
#
#                                             name  \
# 0     STYLISH BEDROOM in VENICE LIDO city centre
# 1                 Venice Blue on Canal apartment
# 2           Venice garden charme and canal view!
# 3              Venice home to relax and emotions
# 4  Charming room with balcony close to S. Mark's
#
#                                              summary  \
# 0  Room situated in a big flat centrally located ...
# 1  I'm thrilled to share my "Blue on Venice Canal...
# 2  I'm thrilled to share my apartment with garden...
# 3  I'm thrilled to share my home to guests coming...
# 4  Few steps from Saint Mark square, on a picture...
#
# ...

# %%
venice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8652 entries, 0 to 8651
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           8652 non-null   int64
#  1   listing_url                  8652 non-null   object
#  2   name                         8652 non-null   object
#  3   summary                      8387 non-null   object
#  4   space                        6843 non-null   object
#  5   description                  8545 non-null   object
#  6   neighborhood_overview        6155 non-null   object
#  7   notes                        5503 non-null   object
#  8   transit                      5872 non-null   object
#  9   access                       4736 non-null   object
#  10  interaction                  5234 non-null   object
#  11  house_rules                  6139 non-null   object
#  12  medium_url                   0 non-null      float64
# ...

# %%
venice.describe()
# Out:
#                  id  medium_url       host_id  host_listings_count  \
# count  8.652000e+03         0.0  8.652000e+03          8651.000000
# mean   2.170998e+07         NaN  9.320394e+07            14.849150
# std    1.287055e+07         NaN  9.632786e+07            58.265287
# min    6.623000e+03         NaN  1.501600e+04             0.000000
# 25%    1.123093e+07         NaN  1.191300e+07             1.000000
# 50%    2.199652e+07         NaN  4.999012e+07             3.000000
# 75%    3.281169e+07         NaN  1.655005e+08            10.000000
# max    4.375383e+07         NaN  3.493171e+08          1448.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                8651.000000  8652.000000  8652.000000   8652.000000
# mean                   14.849150    45.445516    12.318820      3.925220
# std                    58.265287     0.023192     0.040458      1.971963
# ...

# %%
len(venice)
# Out:
# 8652

# %%
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.scatterplot(x = 'price', y = 'number_of_reviews', data = venice,
                 palette ='plasma_r', ci = False)

# %%
venice['price'].mean()
# Out:
# 146.958969024503

# %%
#average price in Venice is $146-147/night.

# %%
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.barplot(x = 'cancellation policy', y = 'number_of_reviews', data = venice,
                 palette ='plasma_r', ci = False)

# %%
#Why is 'strict' and 'strict ' two different values?
venice['cancellation policy'].unique()
# Out:
# array(['strict', 'strict ', 'moderate  ', 'flexible  ', 'super strict ',
#        'luxury moderate', 'super strict'], dtype=object)

# %%
#Affects of review scores on bookability (number of reviews)
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.barplot(x = 'review_scores_rating', y = 'number_of_reviews', data = venice,
                 palette ='plasma_r', ci = False)

# %%
venice['instant_bookable'].count()
# Out:
# 8652

# %%
#Affects of instant_bookable being True on bookability.
#Why are not all the values in the instant_bookable column showing up?
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.barplot(x = 'number_of_reviews', y = 'instant_bookable', data = venice,
                 palette ='plasma', ci = False)

# %%
#How long has the listing been up and how many times it has been booked (reviewed)?
sns.set(rc={'figure.figsize': (16, 5)})
ax = sns.barplot(x = 'dur_in_months', y = 'number_of_reviews', data = venice,
                 palette ='plasma_r', ci = False)
